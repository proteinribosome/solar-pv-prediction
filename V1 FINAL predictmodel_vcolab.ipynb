# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import random
import os

import kagglehub
path = kagglehub.dataset_download("stucom/solar-energy-power-generation-dataset")
csv_path = os.path.join(path, "spg.csv")

SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
# Out:
# Using Colab cache for faster access to the 'solar-energy-power-generation-dataset' dataset.

# %%
df = pd.read_csv(csv_path)
print(f"Columns: {df.columns.tolist()}")
TARGET = 'generated_power_kw'
DROP_COLS = [
    'wind_speed_80_m_above_gnd',
    'wind_direction_80_m_above_gnd',
    'wind_speed_900_mb',
    'wind_direction_900_mb',
    'wind_gust_10_m_above_gnd'
]
df = df.drop(columns=DROP_COLS)

df["cos_zenith"] = np.cos(np.radians(df["zenith"])).clip(lower=0)
df["cos_aoi"]    = np.cos(np.radians(df["angle_of_incidence"])).clip(lower=0)
df["irr_proj"]   = df["shortwave_radiation_backwards_sfc"] * df["cos_aoi"]

y = df[TARGET]
X = df.drop(columns=[TARGET])
# Out:
# Columns: ['temperature_2_m_above_gnd', 'relative_humidity_2_m_above_gnd', 'mean_sea_level_pressure_MSL', 'total_precipitation_sfc', 'snowfall_amount_sfc', 'total_cloud_cover_sfc', 'high_cloud_cover_high_cld_lay', 'medium_cloud_cover_mid_cld_lay', 'low_cloud_cover_low_cld_lay', 'shortwave_radiation_backwards_sfc', 'wind_speed_10_m_above_gnd', 'wind_direction_10_m_above_gnd', 'wind_speed_80_m_above_gnd', 'wind_direction_80_m_above_gnd', 'wind_speed_900_mb', 'wind_direction_900_mb', 'wind_gust_10_m_above_gnd', 'angle_of_incidence', 'zenith', 'azimuth', 'generated_power_kw']

# %%
split_idx = int(len(df) * 0.8)
X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

print(f"Train rows: {len(X_train)} | Test rows: {len(X_test)}")

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

y_scaler = StandardScaler()
y_train_s = y_scaler.fit_transform(np.array(y_train).reshape(-1, 1)).flatten()

features_num = X_train.shape[1]
print(f"Number of features: {features_num}")
# Out:
# Train rows: 3370 | Test rows: 843
# Number of features: 18

# %%
model = keras.Sequential([
    layers.Input(shape=(features_num,)),
    layers.Dense(128, activation="relu"),
    layers.Dropout(0.2),
    layers.Dense(64, activation="relu"),
    layers.Dropout(0.1),
    layers.Dense(32, activation="relu"),
    layers.Dense(1),
])
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mse",
    metrics=[keras.metrics.RootMeanSquaredError(name="rmse")],
)

lr_reducer = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=10, min_lr=1e-6
)

early_stop = keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=50, restore_best_weights=True
)

history = model.fit(
    X_train, y_train_s,
    validation_split=0.2,
    epochs=1000, batch_size=32,
    callbacks=[early_stop, lr_reducer],
    verbose=1,
)
# Out:
# Epoch 1/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 0.4156 - rmse: 0.6446 - val_loss: 0.2915 - val_rmse: 0.5399 - learning_rate: 0.0010
# Epoch 2/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2634 - rmse: 0.5132 - val_loss: 0.2779 - val_rmse: 0.5272 - learning_rate: 0.0010
# Epoch 3/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2495 - rmse: 0.4995 - val_loss: 0.2669 - val_rmse: 0.5166 - learning_rate: 0.0010
# Epoch 4/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2302 - rmse: 0.4798 - val_loss: 0.2685 - val_rmse: 0.5182 - learning_rate: 0.0010
# Epoch 5/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2219 - rmse: 0.4711 - val_loss: 0.2701 - val_rmse: 0.5197 - learning_rate: 0.0010
# Epoch 6/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2143 - rmse: 0.4629 - val_loss: 0.2630 - val_rmse: 0.5128 - learning_rate: 0.0010
# Epoch 7/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2076 - rmse: 0.4556 - val_loss: 0.2583 - val_rmse: 0.5083 - learning_rate: 0.0010
# Epoch 8/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1987 - rmse: 0.4457 - val_loss: 0.2575 - val_rmse: 0.5075 - learning_rate: 0.0010
# Epoch 9/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2015 - rmse: 0.4489 - val_loss: 0.2587 - val_rmse: 0.5086 - learning_rate: 0.0010
# Epoch 10/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1949 - rmse: 0.4415 - val_loss: 0.2536 - val_rmse: 0.5036 - learning_rate: 0.0010
# Epoch 11/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1956 - rmse: 0.4423 - val_loss: 0.2504 - val_rmse: 0.5004 - learning_rate: 0.0010
# Epoch 12/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1919 - rmse: 0.4381 - val_loss: 0.2509 - val_rmse: 0.5009 - learning_rate: 0.0010
# Epoch 13/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1863 - rmse: 0.4316 - val_loss: 0.2561 - val_rmse: 0.5061 - learning_rate: 0.0010
# Epoch 14/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1808 - rmse: 0.4252 - val_loss: 0.2583 - val_rmse: 0.5082 - learning_rate: 0.0010
# Epoch 15/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1794 - rmse: 0.4236 - val_loss: 0.2580 - val_rmse: 0.5079 - learning_rate: 0.0010
# Epoch 16/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1825 - rmse: 0.4272 - val_loss: 0.2559 - val_rmse: 0.5059 - learning_rate: 0.0010
# Epoch 17/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1784 - rmse: 0.4224 - val_loss: 0.2546 - val_rmse: 0.5046 - learning_rate: 0.0010
# Epoch 18/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1742 - rmse: 0.4174 - val_loss: 0.2620 - val_rmse: 0.5119 - learning_rate: 0.0010
# Epoch 19/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1684 - rmse: 0.4104 - val_loss: 0.2516 - val_rmse: 0.5016 - learning_rate: 0.0010
# Epoch 20/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1689 - rmse: 0.4110 - val_loss: 0.2607 - val_rmse: 0.5106 - learning_rate: 0.0010
# Epoch 21/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1670 - rmse: 0.4086 - val_loss: 0.2556 - val_rmse: 0.5055 - learning_rate: 0.0010
# Epoch 22/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1611 - rmse: 0.4013 - val_loss: 0.2534 - val_rmse: 0.5034 - learning_rate: 5.0000e-04
# Epoch 23/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1633 - rmse: 0.4042 - val_loss: 0.2539 - val_rmse: 0.5039 - learning_rate: 5.0000e-04
# Epoch 24/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1578 - rmse: 0.3973 - val_loss: 0.2493 - val_rmse: 0.4993 - learning_rate: 5.0000e-04
# Epoch 25/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1585 - rmse: 0.3981 - val_loss: 0.2587 - val_rmse: 0.5087 - learning_rate: 5.0000e-04
# Epoch 26/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1547 - rmse: 0.3934 - val_loss: 0.2519 - val_rmse: 0.5019 - learning_rate: 5.0000e-04
# Epoch 27/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1563 - rmse: 0.3954 - val_loss: 0.2573 - val_rmse: 0.5072 - learning_rate: 5.0000e-04
# Epoch 28/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1513 - rmse: 0.3890 - val_loss: 0.2578 - val_rmse: 0.5077 - learning_rate: 5.0000e-04
# Epoch 29/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1538 - rmse: 0.3922 - val_loss: 0.2540 - val_rmse: 0.5040 - learning_rate: 5.0000e-04
# Epoch 30/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1492 - rmse: 0.3862 - val_loss: 0.2594 - val_rmse: 0.5093 - learning_rate: 5.0000e-04
# Epoch 31/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1520 - rmse: 0.3899 - val_loss: 0.2554 - val_rmse: 0.5054 - learning_rate: 5.0000e-04
# Epoch 32/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1477 - rmse: 0.3844 - val_loss: 0.2571 - val_rmse: 0.5071 - learning_rate: 5.0000e-04
# Epoch 33/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1518 - rmse: 0.3896 - val_loss: 0.2573 - val_rmse: 0.5072 - learning_rate: 5.0000e-04
# Epoch 34/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1485 - rmse: 0.3854 - val_loss: 0.2642 - val_rmse: 0.5140 - learning_rate: 5.0000e-04
# Epoch 35/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1455 - rmse: 0.3815 - val_loss: 0.2610 - val_rmse: 0.5109 - learning_rate: 2.5000e-04
# Epoch 36/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1371 - rmse: 0.3702 - val_loss: 0.2626 - val_rmse: 0.5124 - learning_rate: 2.5000e-04
# Epoch 37/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1471 - rmse: 0.3835 - val_loss: 0.2608 - val_rmse: 0.5107 - learning_rate: 2.5000e-04
# Epoch 38/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1431 - rmse: 0.3783 - val_loss: 0.2609 - val_rmse: 0.5108 - learning_rate: 2.5000e-04
# Epoch 39/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1378 - rmse: 0.3712 - val_loss: 0.2588 - val_rmse: 0.5087 - learning_rate: 2.5000e-04
# Epoch 40/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1388 - rmse: 0.3725 - val_loss: 0.2598 - val_rmse: 0.5097 - learning_rate: 2.5000e-04
# Epoch 41/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1447 - rmse: 0.3804 - val_loss: 0.2596 - val_rmse: 0.5095 - learning_rate: 2.5000e-04
# Epoch 42/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1366 - rmse: 0.3696 - val_loss: 0.2614 - val_rmse: 0.5113 - learning_rate: 2.5000e-04
# Epoch 43/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1319 - rmse: 0.3632 - val_loss: 0.2593 - val_rmse: 0.5092 - learning_rate: 2.5000e-04
# Epoch 44/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1368 - rmse: 0.3699 - val_loss: 0.2625 - val_rmse: 0.5123 - learning_rate: 2.5000e-04
# Epoch 45/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1325 - rmse: 0.3640 - val_loss: 0.2593 - val_rmse: 0.5092 - learning_rate: 1.2500e-04
# Epoch 46/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1321 - rmse: 0.3634 - val_loss: 0.2625 - val_rmse: 0.5124 - learning_rate: 1.2500e-04
# Epoch 47/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1378 - rmse: 0.3713 - val_loss: 0.2606 - val_rmse: 0.5105 - learning_rate: 1.2500e-04
# Epoch 48/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1321 - rmse: 0.3634 - val_loss: 0.2626 - val_rmse: 0.5125 - learning_rate: 1.2500e-04
# Epoch 49/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1358 - rmse: 0.3685 - val_loss: 0.2615 - val_rmse: 0.5114 - learning_rate: 1.2500e-04
# Epoch 50/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1368 - rmse: 0.3699 - val_loss: 0.2634 - val_rmse: 0.5132 - learning_rate: 1.2500e-04
# Epoch 51/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1385 - rmse: 0.3722 - val_loss: 0.2605 - val_rmse: 0.5104 - learning_rate: 1.2500e-04
# Epoch 52/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1306 - rmse: 0.3614 - val_loss: 0.2613 - val_rmse: 0.5112 - learning_rate: 1.2500e-04
# Epoch 53/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1293 - rmse: 0.3596 - val_loss: 0.2606 - val_rmse: 0.5104 - learning_rate: 1.2500e-04
# Epoch 54/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1280 - rmse: 0.3578 - val_loss: 0.2599 - val_rmse: 0.5098 - learning_rate: 1.2500e-04
# Epoch 55/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1287 - rmse: 0.3588 - val_loss: 0.2599 - val_rmse: 0.5098 - learning_rate: 6.2500e-05
# Epoch 56/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1291 - rmse: 0.3593 - val_loss: 0.2600 - val_rmse: 0.5099 - learning_rate: 6.2500e-05
# Epoch 57/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1290 - rmse: 0.3592 - val_loss: 0.2599 - val_rmse: 0.5098 - learning_rate: 6.2500e-05
# Epoch 58/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1293 - rmse: 0.3595 - val_loss: 0.2607 - val_rmse: 0.5106 - learning_rate: 6.2500e-05
# Epoch 59/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1278 - rmse: 0.3575 - val_loss: 0.2604 - val_rmse: 0.5103 - learning_rate: 6.2500e-05
# Epoch 60/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1270 - rmse: 0.3564 - val_loss: 0.2614 - val_rmse: 0.5113 - learning_rate: 6.2500e-05
# Epoch 61/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1251 - rmse: 0.3537 - val_loss: 0.2612 - val_rmse: 0.5111 - learning_rate: 6.2500e-05
# Epoch 62/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1275 - rmse: 0.3571 - val_loss: 0.2617 - val_rmse: 0.5115 - learning_rate: 6.2500e-05
# Epoch 63/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1317 - rmse: 0.3629 - val_loss: 0.2603 - val_rmse: 0.5102 - learning_rate: 6.2500e-05
# Epoch 64/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1272 - rmse: 0.3566 - val_loss: 0.2604 - val_rmse: 0.5103 - learning_rate: 6.2500e-05
# Epoch 65/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1292 - rmse: 0.3595 - val_loss: 0.2607 - val_rmse: 0.5106 - learning_rate: 3.1250e-05
# Epoch 66/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1265 - rmse: 0.3557 - val_loss: 0.2611 - val_rmse: 0.5110 - learning_rate: 3.1250e-05
# Epoch 67/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1300 - rmse: 0.3605 - val_loss: 0.2616 - val_rmse: 0.5115 - learning_rate: 3.1250e-05
# Epoch 68/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1305 - rmse: 0.3612 - val_loss: 0.2614 - val_rmse: 0.5113 - learning_rate: 3.1250e-05
# Epoch 69/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1265 - rmse: 0.3557 - val_loss: 0.2618 - val_rmse: 0.5117 - learning_rate: 3.1250e-05
# Epoch 70/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1281 - rmse: 0.3579 - val_loss: 0.2616 - val_rmse: 0.5114 - learning_rate: 3.1250e-05
# Epoch 71/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1309 - rmse: 0.3619 - val_loss: 0.2615 - val_rmse: 0.5114 - learning_rate: 3.1250e-05
# Epoch 72/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1309 - rmse: 0.3618 - val_loss: 0.2622 - val_rmse: 0.5120 - learning_rate: 3.1250e-05
# Epoch 73/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1289 - rmse: 0.3590 - val_loss: 0.2623 - val_rmse: 0.5121 - learning_rate: 3.1250e-05
# Epoch 74/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1229 - rmse: 0.3506 - val_loss: 0.2624 - val_rmse: 0.5122 - learning_rate: 3.1250e-05

# %%
y_true = y_test
y_pred = y_scaler.inverse_transform(model.predict(X_test)).flatten()
y_pred = y_pred.clip(min=0)

rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mae  = mean_absolute_error(y_true, y_pred)
r2   = r2_score(y_true, y_pred)
mbe  = np.mean(y_pred - y_true)

print(f"RMSE: {rmse:.2f} kW")
print(f"MAE:  {mae:.2f} kW")
print(f"R²:   {r2:.4f}")
print(f"MBE:  {mbe:.2f} kW")
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# RMSE: 607.11 kW
# MAE:  464.37 kW
# R²:   0.5533
# MBE:  38.57 kW

# %%
def plot_history(history):
    plt.figure(figsize=(10, 5))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Model Loss History')
    plt.xlabel('Epoch')
    plt.ylabel('MSE')
    plt.legend()
    plt.grid(True)
    plt.show()

plot_history(history)

# %%
from sklearn.model_selection import TimeSeriesSplit

X_all = df.drop(columns=[TARGET])
y_all = df[TARGET]

tscv = TimeSeriesSplit(n_splits=5)
rmses, r2s = [], []
for i, (tr, te) in enumerate(tscv.split(X_all), 1):
    sc = StandardScaler()
    Xtr = sc.fit_transform(X_all.iloc[tr])
    Xte = sc.transform(X_all.iloc[te])
    ytr, yte = y_all.iloc[tr], y_all.iloc[te]

    m = HistGradientBoostingRegressor(
        max_iter=600, learning_rate=0.05, max_leaf_nodes=63,
        l2_regularization=1.0, random_state=42,
    )
    m.fit(Xtr, ytr)
    p = m.predict(Xte)
    rm = np.sqrt(mean_squared_error(yte, p)); r = r2_score(yte, p)
    rmses.append(rm); r2s.append(r)
    print(f"fold {i}: RMSE {rm:6.1f}  R2 {r:.3f}")

print(f"\nMEAN: RMSE {np.mean(rmses):.1f} +/- {np.std(rmses):.1f}   R2 {np.mean(r2s):.3f}")
# Out:
# fold 1: RMSE  629.8  R2 0.562
# fold 2: RMSE  409.0  R2 0.808
# fold 3: RMSE  334.5  R2 0.863
# fold 4: RMSE  516.7  R2 0.690
# fold 5: RMSE  649.6  R2 0.489
#
# MEAN: RMSE 507.9 +/- 122.4   R2 0.682

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_true, y_pred, alpha=0.5, label='Predictions')
min_val = min(y_true.min(), y_pred.min())
max_val = max(y_true.max(), y_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], 'r--', linewidth=1.5, label='Ideal')
plt.xlabel('True Values (y_test)')
plt.ylabel('Predicted Values (y_pred)')
plt.title('True vs Predicted Values')
plt.tight_layout()
plt.show()
